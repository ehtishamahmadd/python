# %% [markdown]
# Name    = "Ehtisham Ahmad"
#
# email   = "ehtishamahmed10@gmail.com"

# %% [markdown]
# ## - FAO Dataset practice with pandas and numpy

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# %%
import seaborn as sns
import pandas as pd
sns.set_theme(style="whitegrid")

fao = pd.read_csv("fertilizer_consumption.csv")

sns.boxenplot(x="Item Code", y="Value",
              color="b",
              scale="linear", data=fao)
# Out:
# <AxesSubplot:xlabel='Item Code', ylabel='Value'>

# %%
import seaborn as sns
import pandas as pd
sns.set_theme(style="ticks")
palette = sns.color_palette("rocket_r")
fao = pd.read_csv("fertilizer_consumption.csv")

sns.relplot(
    data=fao,
    x="Year Code", y="Value",
    hue="Item", size="Item Code",
    kind="line", size_order=["3102", "3103","3104"],
    height=5, aspect=.75, facet_kws=dict(sharex=False),
)

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

fao = pd.read_csv("fertilizer_consumption.csv")

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=fao, x="Item Code", y="Value", hue="Item",
              linewidth=1)
sns.despine(left=True)

# %%
import seaborn as sns
import pandas as pd
sns.set_theme(style="whitegrid")

fao = pd.read_csv("fertilizer_consumption.csv")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=fao,
    y="Year", x="Value",
    hue="Item Code", size="Item",
    palette=cmap, sizes=(10, 200),
)
g.set(xscale="log", yscale="log")
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
fao = pd.read_csv("fertilizer_consumption.csv")

#draw a line plot
sns.barplot(x="Item Code", y="Value", hue="Item", data=fao)
plt.show()

# %% [markdown]
# ### - Pandas

# %%
fao.head()
# Out:
#   Domain Code                   Domain  Area Code      Area  Element Code  \
# 0         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 1         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 2         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 3         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 4         RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
#             Element  Item Code                             Item  Year Code  \
# 0  Agricultural Use       3102      Nutrient nitrogen N (total)       1961
# 1  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       1961
# 2  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       1962
# 3  Agricultural Use       3102      Nutrient nitrogen N (total)       1962
# 4  Agricultural Use       3102      Nutrient nitrogen N (total)       1963
#
# ...

# %%
fao.dtypes
# Out:
# Domain Code         object
# Domain              object
# Area Code            int64
# Area                object
# Element Code         int64
# Element             object
# Item Code            int64
# Item                object
# Year Code            int64
# Year                 int64
# Unit                object
# Value                int64
# Flag                object
# Flag Description    object
# dtype: object

# %%
fao.index
# Out:
# RangeIndex(start=0, stop=172, step=1)

# %%
fao.to_numpy()
# Out:
# array([['RFN', 'Fertilizers by Nutrient', 165, ..., 41659, 'Qm',
#         'Official data from questionnaires and/or national sources and/or COMTRADE (reporters)'],
#        ['RFN', 'Fertilizers by Nutrient', 165, ..., 500, 'Qm',
#         'Official data from questionnaires and/or national sources and/or COMTRADE (reporters)'],
#        ['RFN', 'Fertilizers by Nutrient', 165, ..., 210, 'Qm',
#         'Official data from questionnaires and/or national sources and/or COMTRADE (reporters)'],
#        ...,
#        ['RFN', 'Fertilizers by Nutrient', 165, ..., 47260, 'Qm',
#         'Official data from questionnaires and/or national sources and/or COMTRADE (reporters)'],
#        ['RFN', 'Fertilizers by Nutrient', 165, ..., 3505356, 'Qm',
#         'Official data from questionnaires and/or national sources and/or COMTRADE (reporters)'],
#        ['RFN', 'Fertilizers by Nutrient', 165, ..., 1099707, 'Qm',
# ...

# %%
fao.describe()
# Out:
#        Area Code  Element Code    Item Code    Year Code         Year  \
# count      172.0         172.0   172.000000   172.000000   172.000000
# mean       165.0        5157.0  3102.970930  1990.784884  1990.784884
# std          0.0           0.0     0.812385    16.678775    16.678775
# min        165.0        5157.0  3102.000000  1961.000000  1961.000000
# 25%        165.0        5157.0  3102.000000  1976.750000  1976.750000
# 50%        165.0        5157.0  3103.000000  1991.000000  1991.000000
# 75%        165.0        5157.0  3104.000000  2005.000000  2005.000000
# max        165.0        5157.0  3104.000000  2019.000000  2019.000000
#
#               Value
# count  1.720000e+02
# mean   7.064396e+05
# std    9.709749e+05
# min    1.440000e+02
# 25%    2.615950e+04
# 50%    2.689255e+05
# 75%    9.193622e+05
# max    3.505356e+06

# %%
fao.T
# Out:
#                                                                 0    \
# Domain Code                                                     RFN
# Domain                                      Fertilizers by Nutrient
# Area Code                                                       165
# Area                                                       Pakistan
# Element Code                                                   5157
# Element                                            Agricultural Use
# Item Code                                                      3102
# Item                                    Nutrient nitrogen N (total)
# Year Code                                                      1961
# Year                                                           1961
# Unit                                                         tonnes
# Value                                                         41659
# Flag                                                             Qm
# ...

# %%
fao.sort_index(axis=0, ascending=False)
# Out:
#     Domain Code                   Domain  Area Code      Area  Element Code  \
# 171         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 170         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 169         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 168         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 167         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# ..          ...                      ...        ...       ...           ...
# 4           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 3           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 2           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 1           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 0           RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
# ...

# %%
fao.sort_index(axis=1, ascending=False)
# Out:
#      Year Code  Year    Value    Unit  Item Code  \
# 0         1961  1961    41659  tonnes       3102
# 1         1961  1961      500  tonnes       3103
# 2         1962  1962      210  tonnes       3103
# 3         1962  1962    41160  tonnes       3102
# 4         1963  1963    67620  tonnes       3102
# ..         ...   ...      ...     ...        ...
# 167       2018  2018  3446922  tonnes       3102
# 168       2018  2018    54173  tonnes       3104
# 169       2019  2019    47260  tonnes       3104
# 170       2019  2019  3505356  tonnes       3102
# 171       2019  2019  1099707  tonnes       3103
#
#                                 Item  \
# 0        Nutrient nitrogen N (total)
# 1    Nutrient phosphate P2O5 (total)
# 2    Nutrient phosphate P2O5 (total)
# 3        Nutrient nitrogen N (total)
# 4        Nutrient nitrogen N (total)
# ..                               ...
# 167      Nutrient nitrogen N (total)
# 168      Nutrient potash K2O (total)
# ...

# %%
fao.sort_values(by="Item", ascending=True)
# Out:
#     Domain Code                   Domain  Area Code      Area  Element Code  \
# 0           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 38          RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 131         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 41          RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 170         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# ..          ...                      ...        ...       ...           ...
# 84          RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 132         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 133         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 60          RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 85          RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
# ...

# %%
fao["Year"]
# Out:
# 0      1961
# 1      1961
# 2      1962
# 3      1962
# 4      1963
#        ...
# 167    2018
# 168    2018
# 169    2019
# 170    2019
# 171    2019
# Name: Year, Length: 172, dtype: int64

# %%
fao[0:4]
# Out:
#   Domain Code                   Domain  Area Code      Area  Element Code  \
# 0         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 1         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 2         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 3         RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
#             Element  Item Code                             Item  Year Code  \
# 0  Agricultural Use       3102      Nutrient nitrogen N (total)       1961
# 1  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       1961
# 2  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       1962
# 3  Agricultural Use       3102      Nutrient nitrogen N (total)       1962
#
#    Year    Unit  Value Flag                                   Flag Description
# 0  1961  tonnes  41659   Qm  Official data from questionnaires and/or natio...
# ...

# %%
fao.loc[25]
# Out:
# Domain Code                                                       RFN
# Domain                                        Fertilizers by Nutrient
# Area Code                                                         165
# Area                                                         Pakistan
# Element Code                                                     5157
# Element                                              Agricultural Use
# Item Code                                                        3104
# Item                                      Nutrient potash K2O (total)
# Year Code                                                        1971
# Year                                                             1971
# Unit                                                           tonnes
# Value                                                             744
# Flag                                                               Qm
# ...

# %%
fao.loc[:,["Item Code",'Year']]
# Out:
#      Item Code  Year
# 0         3102  1961
# 1         3103  1961
# 2         3103  1962
# 3         3102  1962
# 4         3102  1963
# ..         ...   ...
# 167       3102  2018
# 168       3104  2018
# 169       3104  2019
# 170       3102  2019
# 171       3103  2019
#
# [172 rows x 2 columns]

# %%
fao.loc["0":"11",["Year","Item Code"]]
# Out:
#     Year  Item Code
# 0   1961       3102
# 1   1961       3103
# 2   1962       3103
# 3   1962       3102
# 4   1963       3102
# 5   1963       3103
# 6   1964       3103
# 7   1964       3102
# 8   1965       3102
# 9   1965       3103
# 10  1966       3103
# 11  1966       3102

# %%
fao.loc[[0,11],["Year","Item Code"]]
# Out:
#     Year  Item Code
# 0   1961       3102
# 11  1966       3102

# %%
fao.iloc[3]
# Out:
# Domain Code                                                       RFN
# Domain                                        Fertilizers by Nutrient
# Area Code                                                         165
# Area                                                         Pakistan
# Element Code                                                     5157
# Element                                              Agricultural Use
# Item Code                                                        3102
# Item                                      Nutrient nitrogen N (total)
# Year Code                                                        1962
# Year                                                             1962
# Unit                                                           tonnes
# Value                                                           41160
# Flag                                                               Qm
# ...

# %%
fao.iloc[0:5]
# Out:
#   Domain Code                   Domain  Area Code      Area  Element Code  \
# 0         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 1         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 2         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 3         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 4         RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
#             Element  Item Code                             Item  Year Code  \
# 0  Agricultural Use       3102      Nutrient nitrogen N (total)       1961
# 1  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       1961
# 2  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       1962
# 3  Agricultural Use       3102      Nutrient nitrogen N (total)       1962
# 4  Agricultural Use       3102      Nutrient nitrogen N (total)       1963
#
# ...

# %%
fao.iloc[0:5,0:8]
# Out:
#   Domain Code                   Domain  Area Code      Area  Element Code  \
# 0         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 1         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 2         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 3         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 4         RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
#             Element  Item Code                             Item
# 0  Agricultural Use       3102      Nutrient nitrogen N (total)
# 1  Agricultural Use       3103  Nutrient phosphate P2O5 (total)
# 2  Agricultural Use       3103  Nutrient phosphate P2O5 (total)
# 3  Agricultural Use       3102      Nutrient nitrogen N (total)
# 4  Agricultural Use       3102      Nutrient nitrogen N (total)

# %%
#booleans operators

fao[fao["Year Code"]>2018]
# Out:
#     Domain Code                   Domain  Area Code      Area  Element Code  \
# 169         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 170         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 171         RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
#               Element  Item Code                             Item  Year Code  \
# 169  Agricultural Use       3104      Nutrient potash K2O (total)       2019
# 170  Agricultural Use       3102      Nutrient nitrogen N (total)       2019
# 171  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       2019
#
#      Year    Unit    Value Flag  \
# 169  2019  tonnes    47260   Qm
# 170  2019  tonnes  3505356   Qm
# 171  2019  tonnes  1099707   Qm
#
#                                       Flag Description
# 169  Official data from questionnaires and/or natio...
# 170  Official data from questionnaires and/or natio...
# ...

# %%
fao[fao[["Year Code","Value"]]>2018]
# Out:
#     Domain Code Domain  Area Code Area  Element Code Element  Item Code Item  \
# 0           NaN    NaN        NaN  NaN           NaN     NaN        NaN  NaN
# 1           NaN    NaN        NaN  NaN           NaN     NaN        NaN  NaN
# 2           NaN    NaN        NaN  NaN           NaN     NaN        NaN  NaN
# 3           NaN    NaN        NaN  NaN           NaN     NaN        NaN  NaN
# 4           NaN    NaN        NaN  NaN           NaN     NaN        NaN  NaN
# ..          ...    ...        ...  ...           ...     ...        ...  ...
# 167         NaN    NaN        NaN  NaN           NaN     NaN        NaN  NaN
# 168         NaN    NaN        NaN  NaN           NaN     NaN        NaN  NaN
# 169         NaN    NaN        NaN  NaN           NaN     NaN        NaN  NaN
# 170         NaN    NaN        NaN  NaN           NaN     NaN        NaN  NaN
# 171         NaN    NaN        NaN  NaN           NaN     NaN        NaN  NaN
#
# ...

# %%
#mean of all rows in "mean(row)"
fao['mean']=fao.mean(numeric_only=True, axis=1)
fao
# Out:
#     Domain Code                   Domain  Area Code      Area  Element Code  \
# 0           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 1           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 2           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 3           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 4           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# ..          ...                      ...        ...       ...           ...
# 167         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 168         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 169         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 170         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 171         RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
# ...

# %%
fao=fao.iloc[:, 0:4]
fao
# Out:
#     Domain Code                   Domain  Area Code      Area
# 0           RFN  Fertilizers by Nutrient        165  Pakistan
# 1           RFN  Fertilizers by Nutrient        165  Pakistan
# 2           RFN  Fertilizers by Nutrient        165  Pakistan
# 3           RFN  Fertilizers by Nutrient        165  Pakistan
# 4           RFN  Fertilizers by Nutrient        165  Pakistan
# ..          ...                      ...        ...       ...
# 167         RFN  Fertilizers by Nutrient        165  Pakistan
# 168         RFN  Fertilizers by Nutrient        165  Pakistan
# 169         RFN  Fertilizers by Nutrient        165  Pakistan
# 170         RFN  Fertilizers by Nutrient        165  Pakistan
# 171         RFN  Fertilizers by Nutrient        165  Pakistan
#
# [172 rows x 4 columns]

# %% [markdown]
# ### - Numpy

# %%
fao.to_numpy()
# Out:
# array([['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
# ...

# %%
a= fao.to_numpy()
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
a.shape
# Out:
# (172, 4)

# %%
a.ndim
# Out:
# 2

# %%
a.size
# Out:
# 688

# %%
a.dtype
# Out:
# dtype('O')

# %%
a.itemsize
# Out:
# 8

# %%
a.data

# %%
a.sum(axis=0)
# Out:
# array(['...',
# ...

# %%
a.cumsum(axis=0)
# Out:
# array([['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'],
#        ['RFNRFN', 'Fertilizers by NutrientFertilizers by Nutrient', 330,
#         'PakistanPakistan'],
#        ['RFNRFNRFN',
#         'Fertilizers by NutrientFertilizers by NutrientFertilizers by Nutrient',
#         495, 'PakistanPakistanPakistan'],
#        ['RFNRFNRFNRFN',
#         'Fertilizers by NutrientFertilizers by NutrientFertilizers by NutrientFertilizers by Nutrient',
#         660, 'PakistanPakistanPakistanPakistan'],
#        ['RFNRFNRFNRFNRFN',
#         'Fertilizers by NutrientFertilizers by NutrientFertilizers by NutrientFertilizers by NutrientFertilizers by Nutrient',
#         825, 'PakistanPakistanPakistanPakistanPakistan'],
#        ['RFNRFNRFNRFNRFNRFN',
#         'Fertilizers by NutrientFertilizers by NutrientFertilizers by NutrientFertilizers by NutrientFertilizers by NutrientFertilizers by Nutrient',
#         990, 'PakistanPakistanPakistanPakistanPakistanPakistan'],
# ...

# %%
a[2]
#indexing
# Out:
# array(['RFN', 'Fertilizers by Nutrient', 165, 'Pakistan'], dtype=object)

# %%
a[0:5,2]
# 0-5 row entry and 2nd column
# Out:
# array([165, 165, 165, 165, 165], dtype=object)
