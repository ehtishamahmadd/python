# %% [markdown]
# Name    = "Ehtisham Ahmad"
#
# email   = "ehtishamahmed10@gmail.com"

# %% [markdown]
# ## Notions in Statistics
# Summation
#
# The standard deviation of sample da0ta
#
# The standard deviation of population data
#
# Variance of sample data
#
# Variance of population data
#
# The range of data
#
# The average range pf data
#
# Absolute value of some term
#
# Greater than
#
# Less than
#
# Greater than or equal to
#
# Less than or equal to
#
# An individual value
#
# A particular first value
#
# Mean(average of sample data)
#
# Mean(average of population data)
#
# A portion of sample data
#
# A portion of population data
#
# Sample size
#
# Poplation size
#
# ------------------

# %% [markdown]
# # - Data Types

# %% [markdown]
# ### Cross Sectional:
# Data collected at one point.
#
# ### Time Series:
# Data collected over different time point.
#
# ### Univariate:
# Data conatains a single variable to measure entity.
#
# ### Multi-variate:
# Data conatains more than 2 variables to measure something.
#
# --------------------------------------

# %% [markdown]
# # - Variable Types

# %% [markdown]
# ## - Categorical: (Nominal) (Qualitative(non-numerical))
#
# ### Binomial:
# 2 options(True/False).
#
# ### Multinomial:
# More than 2 options.
#
# ### Ordinal Variable:
# Categorial vairable arranged in an order(High/Medium/Low).
#
# ### Ratio Data:
# Ratio between different values. (Or)
# The ratio data collected on a ratio scale has an equal distance between adjacent values.
#
# ### Interval Variables:
# Ordered and characterized data (Or)
# An interval variable is a one where the difference between two values is meaningful.
#
# ## - Continuous: (Quantitative(numerical))

# %% [markdown]
# --------------

# %% [markdown]
# # - Definitions

# %% [markdown]
# ### Mean: (Average)
# The sum of the numbers divided by how many numbers are in the list.
#
# ### Percentage:
# A rate, number, or amount in each hundred.
#
# ### Likelihood:
# The state or fact of something's being likely; probability
#
# ### Variance:
# The fact or quality of being different, divergent, or inconsistent.
#
# ### T-test:
#
# A t-test is a type of inferential statistic used to determine if there is a significant difference between the means of two groups, which may be related in certain features.
#
# ### Anova:
# Statistical differences between the means of three or more independent groups
#
# ### Population: (N)
# Any specific collection of objects of interest.
#
# ### Sample: (n)
# A subset of population.
#
# ### Measurement:
# Number or attribute computed for each sample.
#
# ### Parameter:
# Summarizes some aspect of the population as a whole.
#
# ### Descriptive Statistics:
# Statistic branch that involves organizing, displaying and describing data.
#
# ### Inferential Statistics:
# Drawn conculsion about a population based on information contained in a sample taken from that population.
#
# ### Qualitative Data: (Categorical)
# Based on non-numerical scale(Attributes, Labels).
#
# ### Quantitative Data: (Continuous)
# Based on numerical scale.
#
# (Mean is meaning ful for interval and ratio data. Outliners change the means of data, therefore, Median is useful.)
#
# ### Median:
# Middle number in a list.
#
# ### Mode:
# Most repeated value in a list.
#
# ### Dispersion: (Range)
# Difference between the maximum and the minimum value.
#
# ### Standard Deviation: (Sq. root of variance)
# A quantity expressing by how much the members of a group differ from the mean value for the group.
#
# (Dispersion change the mean and media because of min and max values)
#
# --------------------------------

# %% [markdown]
# ## - Tests and their types

# %% [markdown]
# ### Parametric test:
# We meet the assumptions(un-equal values) and more reliable results.
#
# ### Non-Parametric test:
# We don't meet the assumptions(equal values based on their rankings) and less reliable results.
#
# ## Step-1 Normality test:
# Bell curve should be normal.
# - Shapiro-Wilk test (Specific{Reliable})
# - Kolmogorov-Smirnov test (General{Less reliable})
#
# ## Step-2 Homogeneity test:
# The variance of the variable in data are equal.
# - Levene's test
#
# ## Step-3 Purpose:
# Knowing the purpose of your research question.
#
# ##  Types of Purposes
# ### Comparsion:
# Differnce.(Male/Female)
#
# ### Relationship:
# Connection, Correlation, Causation, Prediction.(Food relation with fats)
#
# ## Step-4 Data type:
# - Categorical or Continuous.
#
# ## Step-5 Statistical tests:
#
# - Chi-Squared:
#
#     Purpose: Comparison
#
#     Data: Categorical data only
#
#
# - t-test?Anova:
#
#     Purpose: Comparison
#
#     Data: Categorical and continous data only
#
# - Correlation:
#
#     Purpose: Relationship
#
#     Data: Continous data only
#
#
# ------

# %% [markdown]
# ## When and Where to Use tests?

# %% [markdown]
# Parametric Tests(normal distribution)
# ### 1 - Chi-Squared: (for categorical data)
# Types:
# - Chi-Squared test of homogenity
# - Chi-Squared test of independence
#
# When to use:
# - Nothing effects this.
# - Can be used with any number of levels or groups.  (No of males)
#
# ### 2 - t-Test/Anova: (for categorical and continious data)
# Types:
# - One sample t-test(Compare one group with one standard value)
# - Two sample t-test
#     Un-Paired t-test(Compare 2 groups with eachother valuees)
#     Paired t-test(Compare 2 attributes of one group)
#
# - AVOVA (Analysis of variance for 3+ groups involved)
#     One-way Anova(One group analysis) (Males)
#     Two-way Anova(Two group analysis) (Male/Female)
#     Repeated meaures of Anova(3+ paired groups) (Male/Female/Kid)
#
# ### 3 - Correlation: (for continuous data)
# Types:
# - Pearsons's Correlation (one independent and one dependent variable) (weight(dependent) depends on food(independent))
# - Regression (one independent and one dependent variable)       (Mathematical Equation)
#
# # Important things:
# - Data is normally Distributed
# - Follows a Gaussian distribution (a nromal bell curve)
# - Do not make assumption(this will make resluts less reliable)
#
# 1- Normalize your Data
#
#     a- Standaradization
#
#     b- Min-max scaling
#
#     c- Log transformation
#
# 2- Use Alternative Non-Parametric tests. (abnormal distribution)
#
#     a- Chi-Squared
#
#     b- t-Test/Anova
#
#       - One sample Wilcoxon Signed rank test
#
#       - Two sample t-test
#
#         i - Un-Paired t-test(Mann Whiteny's U test)
#
#         ii- Paired t-test(Wilcoxon)
#
#       - AVOVA (Kruskal-Wallis test)
#
#     c- Correlation
#         -Pearson's Correlation(Spearman's Correlation & Kendall's Tau)
#         -Regression
#
# ------------

# %% [markdown]
# ### Types of ANOVA:
# 1- ANOVA(Analysis of variance)
# - One-way Anova: One group gives the significance result.
# - Two-way Anova: 2 factors involved.
# - Repeated measures of Anova (3+ paired groups of paired t-test)
#
# 2- ANCOVA(Analysis of Co-variance)
# - Compare the means of 3+ independent groups which cannot be tested by ANOVA because varoiables are affected by co-variance(pre-test and post-test of class)
#
# 3- MANOVA:
# - Multi-variate analysis of Variance
#
# 4- MANCOVA
# - Multi-variate analysis of Co-variance
#
# --------------------

# %% [markdown]
# ## Some other tests:
#
# 1- Reliability tests:
# - KR 20/21
# - Cronbach's Alpha
#
# 2- Inter-rater Reliability tests
# - Krippendorf's Aplha(Categorical or Continuous)
# - Fleis's Kappa (Only Categorical)
#
# 3- Validity tests
# - Krippendorf's Aplha test
# - Fleis's Kappa test
#
# 4- Sample Size Computation
# - Cochran's Q test
# - Yamanes's test
# - (man more....)
#
# ---------------

# %% [markdown]
# ### If the data is normal --> Parametric Tests
#
# Comparison:
# - t-test
# - 1- One-sample t-test
# - 2- Two-sample t-test
#     a- Un-paired
#     b- Paired
#
# Correlation:
# - Pearson's Correlation
# - Regression
#
# ### If the data is not normal --> Non-Parametric Tests
#
# Comparison:
# - 1- One-sample t-test (One Sample Wilcoxon Signed rank test)
# - 2- Unpaired t-test (Mann Whitney's U-test)
# - 3- Paired t-test (Wilcoxon)
# - 4- ANOVA (Kruskal-Wallis test)
#
# Correlation:
# - Pearson's Correlation (Spearman's Correlation and Kendall's Tau)
# - Regression

# %% [markdown]
# ## Different Research Designs:
#
# - Completely Randomized Design(CRD):
#
# Each experimental unit is randomly assigned to one of the treatments.
#
# - Randomized Complete Block Design:
#
# 2 steps: Make a block and repeat same steps as Completely Randomized Design(CRD).
#
# - Latin Square Design:
#
# Similar to Square\
# Rows = Columns\
# Each experimental unit will get all treatments but in square style.
#
# - Descriptive Research:
#
# Descriptive survey research uses surveys to gather data about varying subjects. This data aims to know the extent to which different conditions can be obtained among these subjects. For example, a researcher wants to determine the qualification of employed professionals in Maryland.
#
# - Experimental Research Design:
#
# It is a study that strictly adheres to a scientific research design. It includes a hypothesis, a variable that can be manipulated by the researcher, and variables that can be measured, calculated and compared. Most importantly, experimental research is completed in a controlled environment.
#
# - Correlation Resaerch Design:
#
# A correlational research design investigates relationships between variables without the researcher controlling or manipulating any of them. A correlation reflects the strength and/or direction of the relationship between two (or more) variables. The direction of a correlation can be either positive or negative
#
# - Diagnostic research design
#
# Diagnostic research design: In a diagnostic research design, the researcher is trying to evaluate the cause of a specific problem or phenomenon. This research design is used to understand more in detail about the factors that are creating problems in the company.
#
# - Explanatory research design
#
# It is conducted for a problem which was not well researched before, demnds priorities, generates operational definitions and provides a better-researched model. It is actually a type of research design which focuses on explaining the aspects of your study in a detailed manner.
